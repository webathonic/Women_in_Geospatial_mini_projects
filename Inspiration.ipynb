# %% [markdown]
# <a href="https://colab.research.google.com/github/webathonic/Women_in_Geospatial_mini_projects/blob/master/Inspiration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Practicals
# ## Welcome to our powerful tutorial center
# ### Where we get to learn 1 + 1 is 2 minus 3

# %%
print('hi')
# Out:
# hi

# %%
# !pip install numpy pandas matplotlib  scikit-learn

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer

# Load the breast cancer dataset
breast_cancer = load_breast_cancer()

# Create a DataFrame
df = pd.DataFrame(data=breast_cancer.data, columns=breast_cancer.feature_names)
#df['target'] = breast_cancer.target

# Display the first five rows
print(df.head(10))
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(df)
# Out:
# (array([[569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [148., 297.,  88.,  28.,   5.,   3.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [569.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
# ...

# %%
df.columns
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'target'],
#       dtype='object')

# %%
import sklearn.datasets

datasets = [attr for attr in dir(sklearn.datasets) if attr.startswith('load_') or attr.startswith('fetch_')]
for dataset_name in datasets:
    print(dataset_name)
# Out:
# fetch_20newsgroups
# fetch_20newsgroups_vectorized
# fetch_california_housing
# fetch_covtype
# fetch_file
# fetch_kddcup99
# fetch_lfw_pairs
# fetch_lfw_people
# fetch_olivetti_faces
# fetch_openml
# fetch_rcv1
# fetch_species_distributions
# load_breast_cancer
# load_diabetes
# load_digits
# load_files
# load_iris
# load_linnerud
# load_sample_image
# load_sample_images
# load_svmlight_file
# load_svmlight_files
# load_wine

# %%
print (f"there are {20 * 24 * 60} minutes in 20 days")
# Out:
# there are 28800 minutes in 20 days

# %% [markdown]
# # Functions in python
# ## Functions Parameters

# %%
def day_to_minutes (num_days, custom_message):
    print(f"There are {num_days * 24 * 60} minutes in {num_days} days")
    print(custom_message)
day_to_minutes(70, "Nicely done")
day_to_minutes(490, "You are too good")
day_to_minutes(3045, "Perfect!")
# Out:
# There are 100800 minutes in 70 days
# Nicely done
# There are 705600 minutes in 490 days
# You are too good
# There are 4384800 minutes in 3045 days
# Perfect!

# %% [markdown]
# #Scope
# ## We have Global and Local Variables

# %%
name_of_unit ="minutes"

def day_to_minutes (num_days, custom_message):
    print(f"There are {num_days * 24 * 60} minutes in {num_days} days")
    print(custom_message)
day_to_minutes(70, "Nicely done")
day_to_minutes(490, "You are too good")
day_to_minutes(3045, "Perfect!")

def scope_check(num_days):
    print(name_of_unit)
    print(num_days)
scope_check(20)
# Out:
# There are 100800 minutes in 70 days
# Nicely done
# There are 705600 minutes in 490 days
# You are too good
# There are 4384800 minutes in 3045 days
# Perfect!
# Hours
# 20

# %% [markdown]
# #User Input
# ##Return
# Datatype - Integer

# %%
name_of_unit ="minutes"

def day_to_minutes (num_days):
    return(f"There are {num_days * 24 * 60} minutes in {num_days} days")

user_input = input("Beautiful one, punch in your desired number of days \n")
user_input_num= int(user_input)
calculated_value = day_to_minutes(user_input_num)
print(calculated_value)
# Out:
# Beautiful one, punch in your desired number of days
# 5
# There are 7200 minutes in 5 days

# %% [markdown]
# #Conditionals
#
# If/Else

# %%
name_of_unit ="minutes"

def day_to_minutes (num_days):
  if num_days > 0:
    return(f"There are {num_days * 24 * 60} minutes in {num_days} days")
  elif num_days == 0:
    return "You have no time to waste"
  #else:
    #return "Invalid number!"
def validate_and_execute():
  if user_input.isdigit():
    user_input_num= int(user_input)
    calculated_value = day_to_minutes(user_input_num)
    print(calculated_value)
  else:
    print("Don't ruin my program buddy, enter a number I say!")

user_input = input("Beautiful one, punch in your desired number of days \n")
validate_and_execute()
# Out:
# Beautiful one, punch in your desired number of days
# 456
# There are 656640 minutes in 456 days

# %%
#making a cleaner code

def day_to_minutes (num_days):
  return(f"There are {num_days * 24 * 60} minutes in {num_days} days")

def validate_and_execute():
  if user_input.isdigit():
    user_input_num= int(user_input)
    if user_input_num > 0:
      calculated_value = day_to_minutes(user_input_num)
      print(calculated_value)
    elif user_input == 0:
      print("You have no time to waste")
  else:
    print("Don't ruin my program buddy, enter a number I say!")

user_input = input("Beautiful one, punch in your desired number of days \n")
validate_and_execute()
# Out:
# Beautiful one, punch in your desired number of days
# -10
# Don't ruin my program buddy, enter a number I say!

# %% [markdown]
# Error handling with try and except

# %%
def day_to_minutes (num_days):
  return(f"There are {num_days * 24 * 60} minutes in {num_days} days")

def validate_and_execute():

  try:
    user_input_num= int(user_input)
    if user_input_num > 0:
      calculated_value = day_to_minutes(user_input_num)
      print(calculated_value)
    elif user_input == 0:
      print("You have no time to waste")
    else:
      print("Invalid number!")
  except:
    print("Don't ruin my program buddy, enter a number I say!")
user_input = ""
while user_input !="exit":
  user_input = input("Beautiful one, punch in your desired number of days \n")
  validate_and_execute()
# Out:
# Beautiful one, punch in your desired number of days
# 4
# There are 5760 minutes in 4 days
# Beautiful one, punch in your desired number of days
# 6
# There are 8640 minutes in 6 days
# Beautiful one, punch in your desired number of days
# exit
# Don't ruin my program buddy, enter a number I say!

# %%
#For loop

def day_to_minutes (num_days):
  return(f"There are {num_days * 24 * 60} minutes in {num_days} days")

def validate_and_execute():

  try:
    user_input_num= int(num_days_element)
    if user_input_num > 0:
      calculated_value = day_to_minutes(user_input_num)
      print(calculated_value)
    elif user_input == 0:
      print("You have no time to waste")
    else:
      print("Invalid number!")
  except:
    print("Don't ruin my program buddy, enter a number I say!")
user_input = ""
while user_input !="exit":
  user_input = input("Beautiful one, punch in your desired number of days \n")
  for num_days_element in user_input.split():
    validate_and_execute()
# Out:
# There are 14400 minutes in 10 days
# There are 28800 minutes in 20 days
# There are 43200 minutes in 30 days
# There are 57600 minutes in 40 days
# There are 72000 minutes in 50 days
# There are 14400 minutes in 10 days
# There are 57600 minutes in 40 days
# Don't ruin my program buddy, enter a number I say!
# Invalid number!
# Don't ruin my program buddy, enter a number I say!

# %% [markdown]
# list,
# .append(),
# selecting elements in a list,
# .remove()
# ##comments - #, """
# ##Sets in python - a list with no duplicate values

# %%
def day_to_minutes (num_days):

  return(f"There are {num_days * 24 * 60} minutes in {num_days} days")

def validate_and_execute():

  try:
    user_input_num= int(num_days_element)
    if user_input_num > 0:
      calculated_value = day_to_minutes(user_input_num)
      print(calculated_value)
    elif user_input == 0:
      print("You have no time to waste")
    else:
      print("Invalid number!")
  except:
    print("Don't ruin my program buddy, enter a number I say!")
user_input = ""
while user_input !="exit":
  user_input = input("Beautiful one, punch in your desired number of days \n")
  for num_days_element in set (user_input.split()):
    validate_and_execute()
for element in set(user_input.split()):
  print(element)
# to add element to a set just do this
set.add(element)
# Out:
# Beautiful one, punch in your desired number of days
# 10 20 30 40 10 50 30
# There are 43200 minutes in 30 days
# There are 72000 minutes in 50 days
# There are 14400 minutes in 10 days
# There are 28800 minutes in 20 days
# There are 57600 minutes in 40 days
# Beautiful one, punch in your desired number of days
# exit
# Don't ruin my program buddy, enter a number I say!
# exit

# %% [markdown]
#   # FUNCTON IN PYTHON
#   ## Built in functions
#   print, int, set, input

# %%
""" Dictionary Data Type- we use key and value in a dict.
if you need to access an element in a dictionary, you use the key and not index
in this case"""
def day_to_minutes (num_days, conversion_unit):
  if conversion_unit == "hours":
     return(f"There are {num_days * 24 } hours in {num_days} days")
  elif conversion_unit == "minutes":
    return(f"There are {num_days * 24 * 60} minutes in {num_days} days")
  elif conversion_unit == "seconds":
    return(f"There are {num_days * 24 * 60*60} seconds in {num_days} days")
  else:
    return "unsupported unit"

def validate_and_execute():

  try:
    user_input_num= int(our_dict["day"])
    if user_input_num > 0:
      calculated_value = day_to_minutes(user_input_num, our_dict["unit"])
      print(calculated_value)
    elif user_input == 0:
      print("You have no time to waste")
    else:
      print("Invalid number!")
  except:
    print("Don't ruin my program buddy, enter a number I say!")
user_input = ""
while user_input !="exit":
  user_input = input("Hey user, enter number of days and conversion unit \n")
  days_unit = user_input.split(":")
  print(days_unit)
  our_dict = {"day": days_unit[0], "unit": days_unit[1]}
  print(our_dict)
  validate_and_execute()
# Out:
# Hey user, enter number of days and conversion unit
# 34: hours
# ['34', ' hours']
# {'day': '34', 'unit': ' hours'}
# unsupported unit
# Hey user, enter number of days and conversion unit
# 34:minutes
# ['34', 'minutes']
# {'day': '34', 'unit': 'minutes'}
# There are 48960 minutes in 34 days
# Hey user, enter number of days and conversion unit
# 34:seonds
# ['34', 'seonds']
# {'day': '34', 'unit': 'seonds'}
# unsupported unit
# Hey user, enter number of days and conversion unit
# 34:seconds
# ['34', 'seconds']
# {'day': '34', 'unit': 'seconds'}
# There are 2937600 seconds in 34 days
# Hey user, enter number of days and conversion unit
# exit
# ['exit']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1264887191.py in <cell line: 0>()
#      30   days_unit = user_input.split(":")
#      31   print(days_unit)
# ...

# %% [markdown]
# #Modularize your project
# modules - .py file that can  be referenced in another file
#
# import thefile
# ###### thefile.validate_and_execute

# %%
# Project: Countdown App
import datetime

user_input=input('Enter your goal with a deadline separated by colon\n')
input_list=user_input.split(':')
goal=input_list[0]
deadline=input_list[1]
deadline_date=datetime.datetime.strptime(deadline, '%d.%m.%Y')
current_date=datetime.datetime.now()
remaining_time=deadline_date-current_date
hours_count= int(remaining_time.total_seconds()/60/60)
print(f'Dear user! Time remaining for your goal: {goal} is in {hours_count} hours ')

#making it cleaner
from datetime import datetime

user_input=input('Enter your goal with a deadline separated by colon\n')
input_list=user_input.split(':')
goal=input_list[0]
deadline=input_list[1]
deadline_date = datetime.strptime(deadline, '%d.%m.%Y')
current_date = datetime.now()
remaining_time = deadline_date-current_date
hours_count= int(remaining_time.total_seconds()/60/60)
print(f'Dear user! Time remaining for your goal: {goal} is in {hours_count} hours ')
# Out:
# Enter your goal with a deadline separated by colon
# qatar:12.12.2026
# Dear user! Time remaining for your goal: qatar is in 7379 hours
